# %% [markdown]
# *   특정 열의 경우 열의 이름이 달라 합쳐지지 않는 경우가 존재했음
# *   따라서 각각의 열들을 확인해가며 진행

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import os

from google.colab import drive

drive.mount("/content/drive")

pd.options.display.max_columns = 999
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # month slice

# %% [markdown]
# ## 2022년 3월

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_03/S-DoT_NATURE_2022.03.07-03.13.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
rename_dot = b01.rename(columns={'기관 명' : '시리얼', '모델명': '구분', '시리얼' : '초미세먼지(㎍/㎥)', '구분' : '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)' : '기온(℃)', '미세먼지(㎍/㎥)' : '상대습도( %)', '기온(℃)' : '풍향(°)',
       '상대습도( %)' : '풍속(m/s)', '풍향(°)' : '돌풍 풍향(°)', '풍속(m/s)' : '돌풍 풍속(m/s)', '돌풍 풍향(°)' : '조도(lux)', '돌풍 풍속(m/s)' : '자외선(UVI)', '조도(lux)' : '소음(dB)',
       '자외선(UVI)' : '진동_x(g)', '소음(dB)' : '진동_y(g)', '진동_x(g)' : '진동_z(g)', '진동_y(g)' : '진동_x 최대(g)', '진동_z(g)' : '진동_y 최대(g)', '진동_x 최대(g)' : '진동_z 최대(g)',
       '진동_y 최대(g)' : '흑구 운도(℃)', '진동_z 최대(g)' : '초미세먼지 보정(㎍/㎥)', '흑구 운도(℃)' : '미세먼지 보정(㎍/㎥)', '초미세먼지 보정(㎍/㎥)' : '전송시간', '미세먼지 보정(㎍/㎥)' : '등록일자',
       '전송시간' : 'none_col1', '등록일자' : 'none_col2'}) # columns이 밀려서 왼쪽으로 2칸씩 재이동

drop_dot = rename_dot.drop(columns = ['none_col1', 'none_col2']) # column 밀림으로 생긴 두 열을 삭제함
index_drop_dot = drop_dot.reset_index(drop=True) # level_0, level_1 컬럼 버림(필요없는 서울시, 기기명 컬럼)
index_drop_dot
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200012   1           5          9    3.5      43.0    NaN
# 1       OC3CL200014   1           3          5    2.7      45.0    NaN
# 2       OC3CL200030   1           6         11   -0.2      49.0    NaN
# 3       OC3CL200035   1           2          4    1.3      51.0    NaN
# 4       OC3CL200048   1           5          8    3.3      41.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 156606  V02Q1941006   1           1          2   13.1      87.0    NaN
# 156607  V02Q1940950   1           6          6   14.0      80.0    NaN
# 156608  V02Q1941013   1          12         12   13.9      85.0    NaN
# 156609  V02Q1940944   1           8          8   14.0      81.0    NaN
# 156610  V02Q1940954   1          22         23   14.7      78.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_03/S-DoT_NATURE_2022.03.14-03.20.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
b02
# Out:
#             모델명          시리얼  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       SDOT001  OC3CL200010          22         35    9.7     100.0    NaN
# 1       SDOT001  OC3CL200011          22         33   21.6      85.0    NaN
# 2       SDOT001  OC3CL200013           5          9   11.1     100.0    NaN
# 3       SDOT001  OC3CL200017           8         12   11.3     100.0    NaN
# 4       SDOT001  OC3CL200027          17         26   10.6      88.0    NaN
# ...         ...          ...         ...        ...    ...       ...    ...
# 171949  SDOT001  V02Q1940941           0          0    5.6      58.0    NaN
# 171950  SDOT001  V02Q1940942           7          7    5.1      44.0    NaN
# 171951  SDOT001  V02Q1940952           8          8    5.4      59.0    NaN
# 171952  SDOT001  V02Q1941015          10         10    5.1      62.0    NaN
# 171953  SDOT001  V02Q1940955           5          5    4.6      61.0    NaN
#
# ...

# %%
result_2203 = pd.concat([index_drop_dot, b02],ignore_index=True)
index_drop_dot.to_csv("2203")

# %% [markdown]
# ## 2022년 1월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_01/S-DoT_NATURE_2022.01.03-01.09.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
b01
# Out:
#                     기관 명  모델명  시리얼   구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  \
# 서울시 SDOT001  OC3CL200017    1    4    7        -3.0         52    NaN
#     SDOT001  OC3CL200014    1    7   11        -2.4         42    NaN
#     SDOT001  OC3CL200011    1    6    9        21.6         85    NaN
#     SDOT001  OC3CL200029    1   13   19        -1.2         44    NaN
#     SDOT001  OC3CL200027    1    7   11        -4.0         37    NaN
# ...                  ...  ...  ...  ...         ...        ...    ...
#     SDOT001  V02Q1940955    1   66   66         2.4         60    NaN
#     SDOT001  V02Q1940953    1   57   57         1.1         64    NaN
#     SDOT001  V02Q1940952    1  101  101         3.6         57    NaN
#     SDOT001  V02Q1941015    1   99   99         2.8         62    NaN
#     SDOT001  V02Q1940954    1   68   69         3.6         54    NaN
#
#              상대습도( %)  풍향(°)  풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  \
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_01/S-DoT_NATURE_2022.01.10-01.16.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
b02
# Out:
#                     기관 명  모델명   시리얼     구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  \
# 서울시 SDOT001  OC3CL200013    1  56.0   81.0        -0.9         82    NaN
#     SDOT001  OC3CL200018    1  69.0  100.0         0.1         80    NaN
#     SDOT001  OC3CL200014    1  51.0   74.0         2.0         64    NaN
#     SDOT001  OC3CL200019    1  50.0   73.0         0.4         70    NaN
#     SDOT001  OC3CL200011    1  48.0   70.0        21.6         85    NaN
# ...                  ...  ...   ...    ...         ...        ...    ...
#     SDOT001  V02Q1940952    1  10.0   10.0        -2.9         40    NaN
#     SDOT001  V02Q1940951    1   5.0    5.0        -3.5         45    NaN
#     SDOT001  V02Q1940955    1   4.0    4.0        -3.8         41    NaN
#     SDOT001  V02Q1941015    1   9.0    9.0        -3.7         39    NaN
#     SDOT001  V02Q1940953    1   4.0    4.0        -2.9         36    NaN
#
#              상대습도( %)  풍향(°)  풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  \
# ...

# %%
a03 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_01/S-DoT_NATURE_2022.01.17-01.23.csv')
b03 = pd.read_csv(a03, encoding='euc-kr')
b03
# Out:
#                     기관 명  모델명  시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  \
# 서울시 SDOT001  OC3CL200012    1    5   8        -4.9         42    NaN
#     SDOT001  OC3CL200017    1    2   3        -5.4         44    NaN
#     SDOT001  OC3CL200019    1    4   7        -6.4         48    NaN
#     SDOT001  OC3CL200020    1    2   3        -5.4         47    NaN
#     SDOT001  OC3CL200013    1    4   6        -7.0         51    NaN
# ...                  ...  ...  ...  ..         ...        ...    ...
#     SDOT001  V02Q1940955    1   44  45         3.5         51    NaN
#     SDOT001  V02Q1941013    1   15  15         4.5         50    NaN
#     SDOT001  V02Q1941006    1    9  13         3.0         56    NaN
#     SDOT001  V02Q1941015    1   64  64         3.9         55    NaN
#     SDOT001  V02Q1941000    1    7  12         4.2         52    NaN
#
#              상대습도( %)  풍향(°)  풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  \
# ...

# %%
a04 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_01/S-DoT_NATURE_2022.01.24-01.30.csv')
b04 = pd.read_csv(a04, encoding='euc-kr')
b04
# Out:
#                     기관 명  모델명  시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  \
# 서울시 SDOT001  OC3CL200011    1   37  54        21.6       85.0    NaN
#     SDOT001  OC3CL200014    1   34  49         3.5       58.0    NaN
#     SDOT001  OC3CL200017    1   26  38         0.7       77.0    NaN
#     SDOT001  OC3CL200020    1   19  28         3.1       62.0    NaN
#     SDOT001  OC3CL200028    1   38  55         2.3       62.0    NaN
# ...                  ...  ...  ...  ..         ...        ...    ...
#     SDOT001  V02Q1940953    1    5   5         0.3       38.0    NaN
#     SDOT001  V02Q1940954    1    9   9         0.3       37.0    NaN
#     SDOT001  V02Q1941006    1    1   2        -0.9       41.0    NaN
#     SDOT001  V02Q1941015    1   11  11        -0.2       40.0    NaN
#     SDOT001  V02Q1940952    1    9   9         0.2       37.0    NaN
#
#              상대습도( %)  풍향(°)  풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  \
# ...

# %%
a05 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_01/S-DoT_NATURE_2022.01.31-02.06.csv')
b05 = pd.read_csv(a05, encoding='euc-kr')
b05
# Out:
#                     기관 명  모델명  시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  \
# 서울시 SDOT001  OC3CL200017    1    4   6        -1.6       45.0    NaN
#     SDOT001  OC3CL200011    1    6   9        21.6       85.0    NaN
#     SDOT001  OC3CL200016    1    6  10        -0.8       42.0    NaN
#     SDOT001  OC3CL200013    1    7  10        -3.4       48.0    NaN
#     SDOT001  OC3CL200012    1    8  13        -0.8       40.0    NaN
# ...                  ...  ...  ...  ..         ...        ...    ...
#     SDOT001  V02Q1940955    1    4   4        -2.3       44.0    NaN
#     SDOT001  V02Q1941013    1    0   0        -1.5       44.0    NaN
#     SDOT001  V02Q1941015    1    9   9        -2.3       43.0    NaN
#     SDOT001  V02Q1941006    1    1   1        -2.5       47.0    NaN
#     SDOT001  V02Q1941000    1    0   0        -2.1       44.0    NaN
#
#              상대습도( %)  풍향(°)  풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  \
# ...

# %%
result_2201 = pd.concat([b01, b02, b03, b04,b05],ignore_index=True)

rename_dot = result_2201.rename(columns={'기관 명' : '시리얼', '모델명': '구분', '시리얼' : '초미세먼지(㎍/㎥)', '구분' : '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)' : '기온(℃)', '미세먼지(㎍/㎥)' : '상대습도( %)', '기온(℃)' : '풍향(°)',
       '상대습도( %)' : '풍속(m/s)', '풍향(°)' : '돌풍 풍향(°)', '풍속(m/s)' : '돌풍 풍속(m/s)', '돌풍 풍향(°)' : '조도(lux)', '돌풍 풍속(m/s)' : '자외선(UVI)', '조도(lux)' : '소음(dB)',
       '자외선(UVI)' : '진동_x(g)', '소음(dB)' : '진동_y(g)', '진동_x(g)' : '진동_z(g)', '진동_y(g)' : '진동_x 최대(g)', '진동_z(g)' : '진동_y 최대(g)', '진동_x 최대(g)' : '진동_z 최대(g)',
       '진동_y 최대(g)' : '흑구 운도(℃)', '진동_z 최대(g)' : '초미세먼지 보정(㎍/㎥)', '흑구 운도(℃)' : '미세먼지 보정(㎍/㎥)', '초미세먼지 보정(㎍/㎥)' : '전송시간', '미세먼지 보정(㎍/㎥)' : '등록일자',
       '전송시간' : 'none_col1', '등록일자' : 'none_col2'}) # columns이 밀려서 왼쪽으로 2칸씩 재이동

drop_dot = rename_dot.drop(columns = ['none_col1', 'none_col2']) # column 밀림으로 생긴 두 열을 삭제함
index_drop_dot = drop_dot.reset_index(drop=True) # level_0, level_1 컬럼 버림(필요없는 서울시, 기기명 컬럼)
index_drop_dot.to_csv("2201")

# %% [markdown]
# ## 2021년 2월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_02/S-DoT_NATURE_2021.02.01-02.07.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
drop01 = b01.drop(columns = ['기관 명', '모델명']) # column 밀림으로 생긴 두 열을 삭제함
drop01
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (6,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)    기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200010   1         8.0       12.0  000-4.5      54.0    NaN
# 1       OC3CL200011   1         9.0       14.0     21.6      88.0    NaN
# 2       OC3CL200014   1         7.0       10.0  000-6.4      46.0    NaN
# 3       OC3CL200017   1         5.0        8.0  000-6.4      48.0    NaN
# 4       OC3CL200020   1         5.0        9.0  000-6.6      48.0    NaN
# ...             ...  ..         ...        ...      ...       ...    ...
# 127868  V02Q1940948   1        27.0       33.0      0.7      43.0    NaN
# 127869  V02Q1940955   1        20.0       20.0     -0.1      48.0    NaN
# 127870  V02Q1940954   1        65.0       76.0      0.5      43.0    NaN
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_02/S-DoT_NATURE_2021.02.08-02.14.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
drop02 = b02.drop(columns = ['기관 명', '모델명']) # column 밀림으로 생긴 두 열을 삭제함
drop02
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200010   1        21.0       30.0   -0.9      45.0    NaN
# 1       OC3CL200011   1        22.0       33.0   21.6      88.0    NaN
# 2       OC3CL200008   1         9.0       13.0   15.3      19.0    NaN
# 3       OC3CL200014   1        22.0       32.0   -1.4      45.0    NaN
# 4       OC3CL200015   1        28.0       42.0   -1.7      45.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 178197  V02Q1940948   1       132.0      133.0   11.0      49.0    NaN
# 178198  V02Q1940889   1        59.0       59.0   11.5      45.0    NaN
# 178199  V02Q1940955   1       119.0      122.0   11.0      48.0    NaN
# 178200  V02Q1940953   1        97.0       99.0   10.0      49.0    NaN
# 178201  V02Q1940950   1        88.0       88.0   11.2      48.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a03 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_02/S-DoT_NATURE_2021.02.15-02.21.csv')
b03 = pd.read_csv(a03, encoding='euc-kr')
drop03 = b03.drop(columns = ['기관 명', '모델명']) # column 밀림으로 생긴 두 열을 삭제함
drop03
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200008   1        63.0       91.0   16.3      27.0    NaN
# 1       OC3CL200010   1        46.0       67.0    6.5      59.0    NaN
# 2       OC3CL200011   1        51.0       73.0   21.6      88.0    NaN
# 3       OC3CL200012   1        89.0      130.0   10.8      43.0    NaN
# 4       OC3CL200013   1        93.0      136.0    8.5      49.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 134285  V02Q1940951   1        20.0       21.0   12.0      62.0    NaN
# 134286  V02Q1940955   1        22.0       23.0   12.5      59.0    NaN
# 134287  V02Q1940950   1        30.0       30.0   12.9      59.0    NaN
# 134288  V02Q1940854   1        37.0       37.0   13.2      57.0    NaN
# 134289  V02Q1940954   1        49.0       59.0   12.8      58.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a04 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_02/S-DoT_NATURE_2021.02.22-02.28.csv')
b04 = pd.read_csv(a04, encoding='euc-kr')
drop04 = b04.drop(columns = ['기관 명', '모델명']) # column 밀림으로 생긴 두 열을 삭제함
drop04
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도(%)  풍향(°)  \
# 0       OC3CL200010   1        17.0       26.0    9.3     61.0    NaN
# 1       OC3CL200011   1        15.0       24.0   21.6     88.0    NaN
# 2       OC3CL200012   1        18.0       28.0   11.1     59.0    NaN
# 3       OC3CL200013   1        17.0       28.0    9.4     66.0    NaN
# 4       OC3CL200014   1        17.0       26.0   10.2     62.0    NaN
# ...             ...  ..         ...        ...    ...      ...    ...
# 121876  V02Q1940954   1        31.0       41.0   15.1     22.0    NaN
# 121877  V02Q1940955   1         5.0        5.0   13.3     24.0    NaN
# 121878  V02Q1941006   1        11.0       18.0   12.8     26.0    NaN
# 121879  V02Q1941013   1         0.0        0.0   13.3     23.0    NaN
# 121880  V02Q1941015   1         1.0        2.0   13.3     26.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동
0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 176549  서울시  SDOT001  V02Q1940954   1        66.0       66.0   11.0      83.0
# 176550  서울시  SDOT001  V02Q1941006   1        30.0       34.0   10.1      92.0
# 176551  서울시  SDOT001  V02Q1941013   1         0.0        0.0    9.8      93.0
# 176552  서울시  SDOT001  V02Q1941015   1         7.0       16.0   10.5      93.0
# 176553  서울시  SDOT001  V02Q1940955   1        36.0       36.0   10.8      84.0
#
# ...

# %%
a05 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_03/S-DoT_NATURE_2021.03.29-04.04.csv')
b05 = pd.read_csv(a05, encoding='euc-kr')
b05
# Out:
#       기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0      서울시  SDOT001  OC3CL200010   1        21.0       31.0    9.2      87.0
# 1      서울시  SDOT001  OC3CL200012   1        37.0       54.0    9.5      95.0
# 2      서울시  SDOT001  OC3CL200011   1        19.0       28.0   21.6      88.0
# 3      서울시  SDOT001  OC3CL200013   1        20.0       30.0    8.3      97.0
# 4      서울시  SDOT001  OC3CL200014   1        31.0       45.0    9.2      91.0
# ...    ...      ...          ...  ..         ...        ...    ...       ...
# 99587  서울시  SDOT001  V02Q1940864   1         4.0        4.0   12.8      48.0
# 99588  서울시  SDOT001  V02Q1940859   1         7.0        7.0   11.2      53.0
# 99589  서울시  SDOT001  V02Q1940876   1         4.0        4.0   11.9      55.0
# 99590  서울시  SDOT001  V02Q1940857   1         7.0        7.0    7.8      75.0
# 99591  서울시  SDOT001  V02Q1940867   1         4.0        4.0   13.1      50.0
#
# ...

# %%
result_2109 = pd.concat([b01, b02, b03, b04, b05],ignore_index=True)
result_2109.drop(columns = ['기관 명', '모델명'], inplace=True)
result_2109.to_csv("2103")

# %% [markdown]
# ## 2021년 4월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_04/S-DoT_NATURE_2021.04.05-04.11.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
b01
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200135   1         2.0        3.0    9.9      51.0
# 1       서울시  SDOT001  OC3CL200147   1         3.0        6.0    9.9      54.0
# 2       서울시  SDOT001  OC3CL200142   1         3.0        5.0    9.5      49.0
# 3       서울시  SDOT001  OC3CL200132   1         2.0        4.0    5.8      81.0
# 4       서울시  SDOT001  OC3CL200145   1         2.0        5.0    9.5      54.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 135428  서울시  SDOT001  V02Q1940843   1        29.0       30.0   17.2      42.0
# 135429  서울시  SDOT001  V02Q1940886   1        22.0       23.0   17.7      41.0
# 135430  서울시  SDOT001  V02Q1940887   1        22.0       23.0   18.8      34.0
# 135431  서울시  SDOT001  V02Q1940942   1        16.0       17.0   17.2      40.0
# 135432  서울시  SDOT001  V02Q1940888   1        29.0       33.0   18.6      34.0
#
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_04/S-DoT_NATURE_2021.04.12-04.18.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
rename_dot2 = b02.rename(columns={'상대습도(%)':'상대습도( %)',	'진동_(x)(g)':'진동_x(g)', '진동_(y)(g)' :'진동_y(g)',	'진동_(z)(g)' :'진동_z(g)', 	'진동_x 최대(g))' : '진동_x 최대(g)', '흑구 온도(℃)' : '흑구 운도(℃)',	'등록 일자' : '등록일자'})
rename_dot2
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200010   1        16.0       26.0   13.1      57.0
# 1       서울시  SDOT001  OC3CL200011   1        17.0       27.0   21.6      88.0
# 2       서울시  SDOT001  OC3CL200012   1        19.0       33.0   17.0      34.0
# 3       서울시  SDOT001  OC3CL200013   1        15.0       25.0   14.6      42.0
# 4       서울시  SDOT001  OC3CL200014   1        19.0       30.0   16.5      39.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 178694  서울시  SDOT001  V02Q1940955   1         7.0        8.0   10.1      64.0
# 178695  서울시  SDOT001  V02Q1941000   1        11.0       16.0   10.0      69.0
# 178696  서울시  SDOT001  V02Q1941006   1        15.0       24.0   10.3      70.0
# 178697  서울시  SDOT001  V02Q1941013   1         0.0        0.0   11.0      63.0
# 178698  서울시  SDOT001  V02Q1941015   1         2.0        5.0   10.2      71.0
#
# ...

# %%
a03 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_04/S-DoT_NATURE_2021.04.19-04.25.csv')
b03 = pd.read_csv(a03, encoding='euc-kr')
rename_dot3 = b03.rename(columns={'상대습도(%)':'상대습도( %)',	'진동_(x)(g)':'진동_x(g)', '진동_(y)(g)' :'진동_y(g)',	'진동_(z)(g)' :'진동_z(g)', 	'진동_x 최대(g))' : '진동_x 최대(g)', '흑구 온도(℃)' : '흑구 운도(℃)',	'등록 일자' : '등록일자'})
rename_dot3
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200010   1         7.0       12.0    6.1      75.0
# 1       서울시  SDOT001  OC3CL200011   1         7.0       11.0   21.6      88.0
# 2       서울시  SDOT001  OC3CL200012   1        10.0       17.0    9.8      60.0
# 3       서울시  SDOT001  OC3CL200013   1         8.0       13.0    7.2      73.0
# 4       서울시  SDOT001  OC3CL200014   1        10.0       16.0    9.6      63.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 178878  서울시  SDOT001  V02Q1940955   1         3.0        3.0   19.3      37.0
# 178879  서울시  SDOT001  V02Q1941000   1         6.0        9.0   19.8      39.0
# 178880  서울시  SDOT001  V02Q1941006   1         8.0       14.0   18.6      45.0
# 178881  서울시  SDOT001  V02Q1941013   1         4.0        4.0   20.7      38.0
# 178882  서울시  SDOT001  V02Q1941015   1         1.0        2.0   19.1      40.0
#
# ...

# %%
a04 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_04/S-DoT_NATURE_2021.04.26-05.02.csv')
b04 = pd.read_csv(a04, encoding='euc-kr')
rename_dot4 = b04.rename(columns={'상대습도(%)':'상대습도( %)',	'진동_(x)(g)':'진동_x(g)', '진동_(y)(g)' :'진동_y(g)',	'진동_(z)(g)' :'진동_z(g)', 	'진동_x 최대(g))' : '진동_x 최대(g)', '흑구 온도(℃)' : '흑구 운도(℃)',	'등록 일자' : '등록일자'})
rename_dot4
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200010   1           2          4   12.1      65.0
# 1       서울시  SDOT001  OC3CL200011   1           2          4   21.6      88.0
# 2       서울시  SDOT001  OC3CL200012   1           3          5   17.2      37.0
# 3       서울시  SDOT001  OC3CL200013   1           2          3   16.4      40.0
# 4       서울시  SDOT001  OC3CL200014   1           2          4   18.4      34.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 178677  서울시  SDOT001  V02Q1940955   1           7          7   12.3      64.0
# 178678  서울시  SDOT001  V02Q1941000   1          11         15   12.3      70.0
# 178679  서울시  SDOT001  V02Q1941006   1          12         19   12.4      72.0
# 178680  서울시  SDOT001  V02Q1941013   1          10         10   12.6      72.0
# 178681  서울시  SDOT001  V02Q1941015   1           1          3   12.8      68.0
#
# ...

# %%
result_2109 = pd.concat([b01, rename_dot2, rename_dot3, rename_dot4],ignore_index=True)
result_2109.drop(columns = ['기관 명', '모델명'], inplace=True)
result_2109.to_csv("2104")

# %% [markdown]
# ## 2021년 5월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21
NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 113448  V02Q1940948   1           7          7   24.9        70    NaN
# 113449  V02Q1940949   1           4          4   24.6        61    NaN
# 113450  V02Q1940947   1          11         11   26.5        61    NaN
# 113451  V02Q1940946   1          10         10   25.0        67    NaN
# 113452  V02Q1940945   1          11         11   25.7        66    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_09/S-DoT_NATURE_2021.09.13-09.19.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
b02.drop(columns = ['기관 명', '모델명'], inplace=True)
b02
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200026   1           9         13   22.8        75    NaN
# 1       OC3CL200030   1           9         14   20.4        98    NaN
# 2       OC3CL200018   1           8         13   22.5        91    NaN
# 3       OC3CL200014   1           7         10   24.9        65    NaN
# 4       OC3CL200031   1           7         10   21.7        90    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 183906  V02Q1940955   1           0          0   24.3        53    NaN
# 183907  V02Q1940953   1           8          8   23.2        64    NaN
# 183908  V02Q1940950   1           2          2   24.0        57    NaN
# 183909  V02Q1940945   1           3          3   25.4        48    NaN
# 183910  V02Q1940944   1           1          1   24.2        56    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a03 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_09/S-DoT_NATURE_2021.09.20-09.26.csv')
b03 = pd.read_csv(a03, encoding='euc-kr')
b03.drop(columns = ['기관 명', '모델명'], inplace=True)
b03.columns
# Out:
# Index(['시리얼', '구분', '초미세먼지(㎍/㎥)', '미세먼지(㎍/㎥)', '기온(℃)', '상대습도( %)', '풍향(°)',
#        '풍속(m/s)', '돌풍 풍향(°)', '돌풍 풍속(m/s)', '조도(lux)', '자외선(UVI)', '소음(dB)',
#        '진동_x(g)', '진동_y(g)', '진동_z(g)', '진동_x 최대(g)', '진동_y 최대(g)',
#        '진동_z 최대(g)', '흑구 운도(℃)', '초미세먼지 보정(㎍/㎥)', '미세먼지 보정(㎍/㎥)', '전송시간',
#        '등록일자'],
#       dtype='object')

# %%
a04 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_09/S-DoT_NATURE_2021.09.27-10.03.csv')
b04 = pd.read_csv(a04, encoding='euc-kr')
b04.drop(columns = ['기관 명', '모델명'], inplace=True)
b04
# Out:
#                시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0      OC3CL200028   1           0          1   22.6        62    NaN
# 1      OC3CL200020   1           0          0   22.2        64    NaN
# 2      OC3CL200029   1           0          0   21.8        64    NaN
# 3      OC3CL200013   1           0          0   21.9        61    NaN
# 4      OC3CL200031   1           0          0   21.8        60    NaN
# ...            ...  ..         ...        ...    ...       ...    ...
# 52503  V02Q1940950   1           6          6   21.2        86    NaN
# 52504  V02Q1940949   1           5          5   20.7        88    NaN
# 52505  V02Q1940948   1           5          5   21.7        88    NaN
# 52506  V02Q1940946   1           6          6   20.7        89    NaN
# 52507  V02Q1940947   1           9          9   20.9        88    NaN
#
#        풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a05 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_09/S-DoT_NATURE_2021.09.30-10.05.csv')
b05 = pd.read_csv(a05, encoding='euc-kr')
b05.drop(columns = ['기관명', '모델명',  '일산화탄소', '이산화질소', '이산화황', '암모니아', '황화수소', '오존'], inplace=True)
b05.columns
# Out:
# Index(['시리얼', '구분', '초미세먼지(㎍/㎥)', '미세먼지(㎍/㎥)', '기온(℃)', '상대습도(%)', '풍향(°)',
#        '풍속(m/s)', '돌풍 풍향(°)', '돌풍 풍속(m/s)', '조도(lux)', '자외선(UVI)', '소음(dB)',
#        '진동_(x)(g)', '진동_(y)(g)', '진동_(z)(g)', '진동_x 최대(g))', '진동_y 최대(g)',
#        '진동_z 최대(g)', '흑구 온도(℃)', '초미세먼지 보정(㎍/㎥)', '미세먼지 보정(㎍/㎥)', '전송시간',
#        '등록 일자'],
#       dtype='object')

# %%
Index(['시리얼', '구분', '초미세먼지(㎍/㎥)', '미세먼지(㎍/㎥)', '기온(℃)', '상대습도( %)', '풍향(°)',
       '풍속(m/s)', '돌풍 풍향(°)', '돌풍 풍속(m/s)', '조도(lux)', '자외선(UVI)', '소음(dB)',
       '진동_x(g)', '진동_y(g)', '진동_z(g)', '진동_x 최대(g)', '진동_y 최대(g)',
       '진동_z 최대(g)', '흑구 운도(℃)', '초미세먼지 보정(㎍/㎥)', '미세먼지 보정(㎍/㎥)', '전송시간',
       '등록일자']
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도(%)  풍향(°)  \
# 0       OC3CL200011   1         0.0        2.0   21.6     88.0    NaN
# 1       OC3CL200012   1         6.0       10.0   19.4    100.0    NaN
# 2       OC3CL200013   1         1.0        2.0   17.3    100.0    NaN
# 3       OC3CL200014   1         4.0        7.0   20.0    100.0    NaN
# 4       OC3CL200016   1         4.0        7.0   19.9    100.0    NaN
# ...             ...  ..         ...        ...    ...      ...    ...
# 157194  V02Q1940955   1         7.0        7.0   24.2     78.0    NaN
# 157195  V02Q1941000   1         8.0       22.0   24.0     81.0    NaN
# 157196  V02Q1941006   1         1.0        2.0   23.3     84.0    NaN
# 157197  V02Q1941013   1         0.0        0.0   24.4     79.0    NaN
# 157198  V02Q1941015   1         0.0        1.0   23.1     82.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_(x)(g)  \
# ...

# %%
rename_dot = b05.rename(columns={'상대습도(%)':'상대습도( %)',	'진동_(x)(g)':'진동_x(g)', '진동_(y)(g)' :'진동_y(g)',	'진동_(z)(g)' :'진동_z(g)', 	'진동_x 최대(g))' : '진동_x 최대(g)', '흑구 온도(℃)' : '흑구 운도(℃)',	'등록 일자' : '등록일자'})

# %%
result_2109 = pd.concat([b01, b02, b03, b04, rename_dot],ignore_index=True)
result_2109
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200135   1         2.0        3.0    9.9      51.0
# 1       서울시  SDOT001  OC3CL200147   1         3.0        6.0    9.9      54.0
# 2       서울시  SDOT001  OC3CL200142   1         3.0        5.0    9.5      49.0
# 3       서울시  SDOT001  OC3CL200132   1         2.0        4.0    5.8      81.0
# 4       서울시  SDOT001  OC3CL200145   1         2.0        5.0    9.5      54.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 850374  서울시  SDOT001  V02Q1940955   1         7.0        7.0   12.3      64.0
# 850375  서울시  SDOT001  V02Q1941000   1        11.0       15.0   12.3      70.0
# 850376  서울시  SDOT001  V02Q1941006   1        12.0       19.0   12.4      72.0
# 850377  서울시  SDOT001  V02Q1941013   1        10.0       10.0   12.6      72.0
# 850378  서울시  SDOT001  V02Q1941015   1         1.0        3.0   12.8      68.0
#
# ...

# %% [markdown]
# ## 2021년 10월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_10/S-DoT_NATURE_2021.10.04-10.10.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
b01
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200011   1         1.0        4.0   21.6      88.0
# 1       서울시  SDOT001  OC3CL200021   1         7.0       13.0   25.4      74.0
# 2       서울시  SDOT001  OC3CL200013   1         4.0        8.0   24.2     100.0
# 3       서울시  SDOT001  OC3CL200031   1         3.0        7.0   24.2     100.0
# 4       서울시  SDOT001  OC3CL200024   1         4.0       11.0   25.5      72.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 127519  서울시  SDOT001  V02Q1941000   1         9.0       23.0   16.9      78.0
# 127520  서울시  SDOT001  V02Q1940955   1         6.0        7.0   16.9      77.0
# 127521  서울시  SDOT001  V02Q1940949   1         5.0        5.0   16.6      84.0
# 127522  서울시  SDOT001  V02Q1940948   1         5.0        5.0   17.6      78.0
# 127523  서울시  SDOT001  V02Q1941013   1         0.0        0.0   15.0      95.0
#
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21
0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 168675  서울시  SDOT001  V02Q1940952   1          33         33    9.9      40.0
# 168676  서울시  SDOT001  V02Q1940955   1          17         17    8.2      41.0
# 168677  서울시  SDOT001  V02Q1941015   1           5         11    8.4      53.0
# 168678  서울시  SDOT001  V02Q1941013   1           2          2   10.2      44.0
# 168679  서울시  SDOT001  V02Q1941006   1           6          8    8.2      50.0
#
# ...

# %%
a06 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_11/S-DoT_NATURE_2021.11.29-12.05.csv')
b06 = pd.read_csv(a06, encoding='euc-kr')
b06
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200021   1        38.0       56.0    7.3      48.0
# 1       서울시  SDOT001  OC3CL200014   1        27.0       40.0    7.9      46.0
# 2       서울시  SDOT001  OC3CL200026   1        29.0       42.0    4.8      60.0
# 3       서울시  SDOT001  OC3CL200018   1        34.0       50.0    5.5      70.0
# 4       서울시  SDOT001  OC3CL200022   1        15.0       22.0    6.6      47.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 508993  서울시  SDOT001  V02Q1940955   3        17.0       17.0    5.8      50.0
# 508994  서울시  SDOT001  V02Q1941013   3         0.0        0.0    7.6      46.0
# 508995  서울시  SDOT001  V02Q1941006   3         4.0        5.0    5.4      50.0
# 508996  서울시  SDOT001  V02Q1941015   3         3.0        6.0    5.8      49.0
# 508997  서울시  SDOT001  V02Q1941000   3         4.0        7.0    5.7      50.0
#
# ...

# %%
result_2112 = pd.concat([b01, b02, b03, b04, b05, b06],ignore_index=True)
result_2112.drop(columns = ['기관 명', '모델명'], inplace=True)
result_2112.to_csv("2111")

# %%
result_2112
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200016   1          26         37   14.2     100.0    NaN
# 1       OC3CL200030   1          16         23   11.7     100.0    NaN
# 2       OC3CL200028   1          24         35   13.9     100.0    NaN
# 3       OC3CL200023   1          31         45   13.9     100.0    NaN
# 4       OC3CL200013   1          22         32   11.7     100.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 676955  V02Q1940951   1           2          2   18.4      43.0    NaN
# 676956  V02Q1940952   1           2          2   18.1      44.0    NaN
# 676957  V02Q1940950   1           2          2   18.0      46.0    NaN
# 676958  V02Q1940953   1           2          2   17.6      45.0    NaN
# 676959  V02Q1940949   1           1          1   17.9      44.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %% [markdown]
# ## 2021년 12월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_12/S-DoT_NATURE_2021.12.06-12.12.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
c01 = b01.drop(columns = ['기관 명', '모델명']) # column 밀림으로 생긴 두 열을 삭제함
c01
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200023   1        29.0       42.0    4.7      58.0    NaN
# 1       OC3CL200011   1        17.0       25.0   21.6      88.0    NaN
# 2       OC3CL200018   1        24.0       36.0    2.4      80.0    NaN
# 3       OC3CL200013   1        15.0       23.0    2.8      57.0    NaN
# 4       OC3CL200022   1        16.0       24.0    3.9      61.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 510258  V02Q1941013   3         0.0        0.0   -0.4      40.0    NaN
# 510259  V02Q1941015   3         0.0        1.0   -1.6      41.0    NaN
# 510260  V02Q1941006   3         0.0        1.0   -1.8      45.0    NaN
# 510261  V02Q1940954   3         4.0        4.0   -1.4      38.0    NaN
# 510262  V02Q1940953   3         2.0        2.0   -1.3      40.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_12/S-DoT_NATURE_2021.12.13-12.19.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
c02 = b02.drop(columns = ['기관 명', '모델명'])
c02
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200011   1         2.0        4.0   21.6      88.0    NaN
# 1       OC3CL200013   1         2.0        4.0   -3.8      50.0    NaN
# 2       OC3CL200012   1         3.0        6.0   -2.4      42.0    NaN
# 3       OC3CL200018   1         3.0        5.0   -1.9      42.0    NaN
# 4       OC3CL200022   1         2.0        3.0   -2.9      43.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 509620  V02Q1940945   3        18.0       18.0    3.6      66.0    NaN
# 509621  V02Q1940950   3         9.0        9.0    2.4      63.0    NaN
# 509622  V02Q1940946   3        10.0       11.0    4.0      62.0    NaN
# 509623  V02Q1940949   3         5.0        5.0    2.0      66.0    NaN
# 509624  V02Q1941013   3         0.0        0.0    4.5      62.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a03 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_12/S-DoT_NATURE_2021.12.20-12.26.csv')
b03 = pd.read_csv(a03, encoding='euc-kr')
c03 = b03.drop(columns = ['기관 명', '모델명'])
c03
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200014   1         9.0       14.0    2.2      82.0    NaN
# 1       OC3CL200020   1         3.0        5.0    1.9      82.0    NaN
# 2       OC3CL200018   1         9.0       14.0    1.8      84.0    NaN
# 3       OC3CL200013   1         6.0        9.0    0.2     100.0    NaN
# 4       OC3CL200012   1        10.0       15.0    1.9      79.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 509085  V02Q1941006   3         1.0        1.0   -9.8      45.0    NaN
# 509086  V02Q1940952   3        13.0       13.0   -8.9      40.0    NaN
# 509087  V02Q1941013   3         0.0        0.0   -8.5      40.0    NaN
# 509088  V02Q1940955   3         4.0        4.0   -9.7      44.0    NaN
# 509089  V02Q1941015   3        11.0       11.0   -9.4      44.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a04 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_12/S-DoT_NATURE_2021.12.27-01.02.csv')
b04 = pd.read_csv(a04, encoding='euc-kr')
rename_dot = b04.rename(columns={'기관 명' : '시리얼', '모델명': '구분', '시리얼' : '초미세먼지(㎍/㎥)', '구분' : '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)' : '기온(℃)', '미세먼지(㎍/㎥)' : '상대습도( %)', '기온(℃)' : '풍향(°)',
       '상대습도( %)' : '풍속(m/s)', '풍향(°)' : '돌풍 풍향(°)', '풍속(m/s)' : '돌풍 풍속(m/s)', '돌풍 풍향(°)' : '조도(lux)', '돌풍 풍속(m/s)' : '자외선(UVI)', '조도(lux)' : '소음(dB)',
       '자외선(UVI)' : '진동_x(g)', '소음(dB)' : '진동_y(g)', '진동_x(g)' : '진동_z(g)', '진동_y(g)' : '진동_x 최대(g)', '진동_z(g)' : '진동_y 최대(g)', '진동_x 최대(g)' : '진동_z 최대(g)',
       '진동_y 최대(g)' : '흑구 운도(℃)', '진동_z 최대(g)' : '초미세먼지 보정(㎍/㎥)', '흑구 운도(℃)' : '미세먼지 보정(㎍/㎥)', '초미세먼지 보정(㎍/㎥)' : '전송시간', '미세먼지 보정(㎍/㎥)' : '등록일자',
       '전송시간' : 'none_col1', '등록일자' : 'none_col2'}) # columns이 밀려서 왼쪽으로 2칸씩 재이동

drop_dot = rename_dot.drop(columns = ['none_col1', 'none_col2']) # column 밀림으로 생긴 두 열을 삭제함
index_drop_dot = drop_dot.reset_index(drop=True) # level_0, level_1 컬럼 버림(필요없는 서울시, 기기명 컬럼)
index_drop_dot
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200025   1           7         10  -11.3        47    NaN
# 1       OC3CL200014   1           5          8  -10.2        44    NaN
# 2       OC3CL200023   1           7         10  -10.1        42    NaN
# 3       OC3CL200017   1          11         16  -10.2        42    NaN
# 4       OC3CL200021   1           8         13  -10.6        44    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 168504  V02Q1940955   1           6          6   -1.6        42    NaN
# 168505  V02Q1941013   1           0          0   -0.3        33    NaN
# 168506  V02Q1940953   1           6          6   -0.8        40    NaN
# 168507  V02Q1940954   1          10         10   -0.8        40    NaN
# 168508  V02Q1941000   1           1          2   -1.1        34    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
result_2112 = pd.concat([c01, c02, c03, index_drop_dot],ignore_index=True)
result_2112.to_csv("2112")

# %% [markdown]
# ## 2021년 1월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_01/S-DoT_NATURE_2021.01.04-01.10.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
b01
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)    기온(℃)  \
# 0       서울시  SDOT001  V02Q1940043   1         7.0       12.0  000-1.4
# 1       서울시  SDOT001  V02Q1940046   1         4.0        9.0  000-1.8
# 2       서울시  SDOT001  V02Q1940044   1         5.0        7.0  000-1.5
# 3       서울시  SDOT001  V02Q1940049   1         8.0       15.0  000-1.7
# 4       서울시  SDOT001  V02Q1940050   1         8.0       13.0  000-2.6
# ...     ...      ...          ...  ..         ...        ...      ...
# 138015  서울시  SDOT001  V02Q1940954   1        57.0       67.0  000-2.6
# 138016  서울시  SDOT001  V02Q1940952   1         5.0        6.0  000-2.1
# 138017  서울시  SDOT001  V02Q1940955   1        10.0       10.0  000-3.8
# 138018  서울시  SDOT001  V02Q1940947   1         3.0        4.0  000-1.5
# 138019  서울시  SDOT001  V02Q1940951   1         9.0       10.0  000-2.3
#
#         상대습도( %)  풍향(°)  풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  \
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_01/S-DoT_NATURE_2021.01.11-01.17.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
b02
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)    기온(℃)  \
# 0       서울시  SDOT001  OC3CL200010   1         9.0       13.0  00-10.1
# 1       서울시  SDOT001  OC3CL200011   1        12.0       18.0     21.6
# 2       서울시  SDOT001  OC3CL200012   1        12.0       17.0  000-4.8
# 3       서울시  SDOT001  OC3CL200014   1        12.0       19.0  000-5.2
# 4       서울시  SDOT001  OC3CL200016   1        12.0       18.0  000-4.6
# ...     ...      ...          ...  ..         ...        ...      ...
# 150480  서울시  SDOT001  V02Q1940950   1        12.0       12.0  000-0.9
# 150481  서울시  SDOT001  V02Q1940948   1        16.0       20.0      1.8
# 150482  서울시  SDOT001  V02Q1940889   1         7.0       10.0      0.3
# 150483  서울시  SDOT001  V02Q1941013   1         0.0        0.0  000-1.0
# 150484  서울시  SDOT001  V02Q1941015   1        10.0       16.0  000-1.9
#
#         상대습도( %)  풍향(°)  풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  \
# ...

# %%
a03 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_01/S-DoT_NATURE_2021.01.18-01.24.csv')
b03 = pd.read_csv(a03, encoding='euc-kr')
b03
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)    기온(℃)  \
# 0      서울시  SDOT001  OC3CL200015   1         7.0       11.0  000-2.4
# 1      서울시  SDOT001  OC3CL200017   1         4.0        7.0  000-2.9
# 2      서울시  SDOT001  OC3CL200010   1         5.0        7.0  000-2.6
# 3      서울시  SDOT001  OC3CL200011   1         6.0        9.0     21.6
# 4      서울시  SDOT001  OC3CL200012   1         8.0       12.0  000-2.2
# ...    ...      ...          ...  ..         ...        ...      ...
# 78797  서울시  SDOT001  V02Q1940943   1         8.0       10.0       12
# 78798  서울시  SDOT001  V02Q1940954   1        11.0       14.0     12.7
# 78799  서울시  SDOT001  V02Q1940942   1        14.0       14.0       11
# ...

# %%
a04 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/21_01/S-DoT_NATURE_2021.01.25-01.31.csv')
b04 = pd.read_csv(a04, encoding='euc-kr')
c4 = b04.rename(columns={'상대습도(%)':'상대습도( %)',	'진동_(x)(g)':'진동_x(g)', '진동_(y)(g)' :'진동_y(g)',	'진동_(z)(g)' :'진동_z(g)', 	'진동_x 최대(g))' : '진동_x 최대(g)', '흑구 온도(℃)' : '흑구 운도(℃)',	'등록 일자' : '등록일자'})
c4
# Out:
#        기관 명      모델명          시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  \
# 0       서울시  SDOT001  OC3CL200010   1         4.0        7.0    2.2      77.0
# 1       서울시  SDOT001  OC3CL200011   1         8.0       13.0   21.6      88.0
# 2       서울시  SDOT001  OC3CL200012   1        12.0       18.0    6.6      61.0
# 3       서울시  SDOT001  OC3CL200013   1         7.0       10.0    5.1      66.0
# 4       서울시  SDOT001  OC3CL200014   1        10.0       15.0    6.2      63.0
# ...     ...      ...          ...  ..         ...        ...    ...       ...
# 178801  서울시  SDOT001  V02Q1940954   1        58.0       73.0   10.0      51.0
# 178802  서울시  SDOT001  V02Q1940955   1        17.0       20.0    7.8      55.0
# 178803  서울시  SDOT001  V02Q1941006   1        22.0       41.0    9.3      56.0
# 178804  서울시  SDOT001  V02Q1941013   1         0.0        0.0   10.3      52.0
# 178805  서울시  SDOT001  V02Q1941015   1         6.0       15.0    8.3      55.0
#
# ...

# %%
result_2109 = pd.concat([b01, b02, b03, c4],ignore_index=True)
result_2109.drop(columns = ['기관 명', '모델명'], inplace=True)
result_2109.to_csv("2101")

# %% [markdown]
# ## 2021년 2월(완료)

# %%
a01 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_02/S-DoT_NATURE_2022.02.07-02.13.csv')
b01 = pd.read_csv(a01, encoding='euc-kr')
rename_dot = b01.rename(columns={'기관 명' : '시리얼', '모델명': '구분', '시리얼' : '초미세먼지(㎍/㎥)', '구분' : '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)' : '기온(℃)', '미세먼지(㎍/㎥)' : '상대습도( %)', '기온(℃)' : '풍향(°)',
       '상대습도( %)' : '풍속(m/s)', '풍향(°)' : '돌풍 풍향(°)', '풍속(m/s)' : '돌풍 풍속(m/s)', '돌풍 풍향(°)' : '조도(lux)', '돌풍 풍속(m/s)' : '자외선(UVI)', '조도(lux)' : '소음(dB)',
       '자외선(UVI)' : '진동_x(g)', '소음(dB)' : '진동_y(g)', '진동_x(g)' : '진동_z(g)', '진동_y(g)' : '진동_x 최대(g)', '진동_z(g)' : '진동_y 최대(g)', '진동_x 최대(g)' : '진동_z 최대(g)',
       '진동_y 최대(g)' : '흑구 운도(℃)', '진동_z 최대(g)' : '초미세먼지 보정(㎍/㎥)', '흑구 운도(℃)' : '미세먼지 보정(㎍/㎥)', '초미세먼지 보정(㎍/㎥)' : '전송시간', '미세먼지 보정(㎍/㎥)' : '등록일자',
       '전송시간' : 'none_col1', '등록일자' : 'none_col2'}) # columns이 밀려서 왼쪽으로 2칸씩 재이동

drop_dot = rename_dot.drop(columns = ['none_col1', 'none_col2']) # column 밀림으로 생긴 두 열을 삭제함
c1 = drop_dot.reset_index(drop=True) # level_0, level_1 컬럼 버림(필요없는 서울시, 기기명 컬럼)
c1
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200014   1           4          6   -3.2        45    NaN
# 1       OC3CL200011   1           4          7   21.6        85    NaN
# 2       OC3CL200016   1           4          7   -3.0        46    NaN
# 3       OC3CL200021   1           7         10   -3.6        45    NaN
# 4       OC3CL200026   1           4          6   -4.2        48    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 170106  V02Q1940952   1          43         43    7.9        42    NaN
# 170107  V02Q1940953   1          15         15    5.9        46    NaN
# 170108  V02Q1940951   1          22         22    6.2        45    NaN
# 170109  V02Q1941006   1           4          5    5.2        46    NaN
# 170110  V02Q1941015   1          36         36    6.3        48    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a02 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_02/S-DoT_NATURE_2022.02.14-02.20.csv')
b02 = pd.read_csv(a02, encoding='euc-kr')
rename_dot = b02.rename(columns={'기관 명' : '시리얼', '모델명': '구분', '시리얼' : '초미세먼지(㎍/㎥)', '구분' : '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)' : '기온(℃)', '미세먼지(㎍/㎥)' : '상대습도( %)', '기온(℃)' : '풍향(°)',
       '상대습도( %)' : '풍속(m/s)', '풍향(°)' : '돌풍 풍향(°)', '풍속(m/s)' : '돌풍 풍속(m/s)', '돌풍 풍향(°)' : '조도(lux)', '돌풍 풍속(m/s)' : '자외선(UVI)', '조도(lux)' : '소음(dB)',
       '자외선(UVI)' : '진동_x(g)', '소음(dB)' : '진동_y(g)', '진동_x(g)' : '진동_z(g)', '진동_y(g)' : '진동_x 최대(g)', '진동_z(g)' : '진동_y 최대(g)', '진동_x 최대(g)' : '진동_z 최대(g)',
       '진동_y 최대(g)' : '흑구 운도(℃)', '진동_z 최대(g)' : '초미세먼지 보정(㎍/㎥)', '흑구 운도(℃)' : '미세먼지 보정(㎍/㎥)', '초미세먼지 보정(㎍/㎥)' : '전송시간', '미세먼지 보정(㎍/㎥)' : '등록일자',
       '전송시간' : 'none_col1', '등록일자' : 'none_col2'}) # columns이 밀려서 왼쪽으로 2칸씩 재이동

drop_dot = rename_dot.drop(columns = ['none_col1', 'none_col2']) # column 밀림으로 생긴 두 열을 삭제함
c2 = drop_dot.reset_index(drop=True) # level_0, level_1 컬럼 버림(필요없는 서울시, 기기명 컬럼)
c2
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200018   1        20.0       30.0    6.1      49.0    NaN
# 1       OC3CL200022   1        16.0       24.0    4.9      51.0    NaN
# 2       OC3CL200023   1        27.0       39.0    5.7      48.0    NaN
# 3       OC3CL200031   1        28.0       41.0    2.6      49.0    NaN
# 4       OC3CL200027   1        16.0       24.0    3.0      54.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 171701  V02Q1940954   1         7.0        7.0   -2.0      39.0    NaN
# 171702  V02Q1941015   1         9.0        9.0   -2.6      37.0    NaN
# 171703  V02Q1941013   1         0.0        0.0   -1.4      38.0    NaN
# 171704  V02Q1941006   1         1.0        2.0   -2.7      42.0    NaN
# 171705  V02Q1941000   1         NaN        NaN   -2.4      42.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a03 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_02/S-DoT_NATURE_2022.02.21-02.27.csv')
b03 = pd.read_csv(a03, encoding='euc-kr')
rename_dot = b03.rename(columns={'기관 명' : '시리얼', '모델명': '구분', '시리얼' : '초미세먼지(㎍/㎥)', '구분' : '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)' : '기온(℃)', '미세먼지(㎍/㎥)' : '상대습도( %)', '기온(℃)' : '풍향(°)',
       '상대습도( %)' : '풍속(m/s)', '풍향(°)' : '돌풍 풍향(°)', '풍속(m/s)' : '돌풍 풍속(m/s)', '돌풍 풍향(°)' : '조도(lux)', '돌풍 풍속(m/s)' : '자외선(UVI)', '조도(lux)' : '소음(dB)',
       '자외선(UVI)' : '진동_x(g)', '소음(dB)' : '진동_y(g)', '진동_x(g)' : '진동_z(g)', '진동_y(g)' : '진동_x 최대(g)', '진동_z(g)' : '진동_y 최대(g)', '진동_x 최대(g)' : '진동_z 최대(g)',
       '진동_y 최대(g)' : '흑구 운도(℃)', '진동_z 최대(g)' : '초미세먼지 보정(㎍/㎥)', '흑구 운도(℃)' : '미세먼지 보정(㎍/㎥)', '초미세먼지 보정(㎍/㎥)' : '전송시간', '미세먼지 보정(㎍/㎥)' : '등록일자',
       '전송시간' : 'none_col1', '등록일자' : 'none_col2'}) # columns이 밀려서 왼쪽으로 2칸씩 재이동

drop_dot = rename_dot.drop(columns = ['none_col1', 'none_col2']) # column 밀림으로 생긴 두 열을 삭제함
c3 = drop_dot.reset_index(drop=True) # level_0, level_1 컬럼 버림(필요없는 서울시, 기기명 컬럼)
c3
# Out:
#                 시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0       OC3CL200017   1         3.0        5.0   -3.6      43.0    NaN
# 1       OC3CL200012   1         7.0       11.0   -3.1      39.0    NaN
# 2       OC3CL200018   1         7.0       10.0   -2.8      38.0    NaN
# 3       OC3CL200014   1         5.0        8.0   -3.4      39.0    NaN
# 4       OC3CL200026   1         4.0        7.0   -4.1      41.0    NaN
# ...             ...  ..         ...        ...    ...       ...    ...
# 170982  V02Q1941015   1         8.0        8.0    5.8      72.0    NaN
# 170983  V02Q1940955   1         5.0        6.0    5.6      70.0    NaN
# 170984  V02Q1940953   1         2.0        2.0    5.7      67.0    NaN
# 170985  V02Q1940952   1         7.0        8.0    6.2      68.0    NaN
# 170986  V02Q1940948   1         6.0        6.0    6.8      67.0    NaN
#
#         풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
a04 = ('/content/drive/MyDrive/Colab Notebooks/Project/학부연구생/미세먼지_취약계층/data/origin_data/22_02/S-DoT_NATURE_2022.02.28-03.06.csv')
b04 = pd.read_csv(a04, encoding='euc-kr')
rename_dot = b04.rename(columns={'기관 명' : '시리얼', '모델명': '구분', '시리얼' : '초미세먼지(㎍/㎥)', '구분' : '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)' : '기온(℃)', '미세먼지(㎍/㎥)' : '상대습도( %)', '기온(℃)' : '풍향(°)',
       '상대습도( %)' : '풍속(m/s)', '풍향(°)' : '돌풍 풍향(°)', '풍속(m/s)' : '돌풍 풍속(m/s)', '돌풍 풍향(°)' : '조도(lux)', '돌풍 풍속(m/s)' : '자외선(UVI)', '조도(lux)' : '소음(dB)',
       '자외선(UVI)' : '진동_x(g)', '소음(dB)' : '진동_y(g)', '진동_x(g)' : '진동_z(g)', '진동_y(g)' : '진동_x 최대(g)', '진동_z(g)' : '진동_y 최대(g)', '진동_x 최대(g)' : '진동_z 최대(g)',
       '진동_y 최대(g)' : '흑구 운도(℃)', '진동_z 최대(g)' : '초미세먼지 보정(㎍/㎥)', '흑구 운도(℃)' : '미세먼지 보정(㎍/㎥)', '초미세먼지 보정(㎍/㎥)' : '전송시간', '미세먼지 보정(㎍/㎥)' : '등록일자',
       '전송시간' : 'none_col1', '등록일자' : 'none_col2'}) # columns이 밀려서 왼쪽으로 2칸씩 재이동

drop_dot = rename_dot.drop(columns = ['none_col1', 'none_col2']) # column 밀림으로 생긴 두 열을 삭제함
c4 = drop_dot.reset_index(drop=True) # level_0, level_1 컬럼 버림(필요없는 서울시, 기기명 컬럼)
c4
# Out:
#                시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0      OC3CL200011   1           6         10   21.6        85    NaN
# 1      OC3CL200014   1           4          7    5.7        89    NaN
# 2      OC3CL200013   1           6         10    2.7       100    NaN
# 3      OC3CL200012   1           8         12    5.6        79    NaN
# 4      OC3CL200016   1           4          7    5.5        86    NaN
# ...            ...  ..         ...        ...    ...       ...    ...
# 28496  V02Q1940949   1           3          3    3.8        40    NaN
# 28497  V02Q1940951   1           5          5    3.6        43    NaN
# 28498  V02Q1940952   1           5          5    4.0        45    NaN
# 28499  V02Q1940954   1           4          4    4.0        44    NaN
# 28500  V02Q1941015   1           5          5    3.4        45    NaN
#
#        풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
result_2109 = pd.concat([c1,c2,c3,c4],ignore_index=True)


result_2109.to_csv("2202")

# %% [markdown]
# # month merge

# %%
S_DoT1 = pd.concat([dot_2101, dot_2102, dot_2103],ignore_index=True)
S_DoT1.to_csv("S_DoT1")
# Out:
#                  시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)    기온(℃)  상대습도( %)  풍향(°)  \
# 0        V02Q1940043   1         7.0       12.0  000-1.4      32.0    NaN
# 1        V02Q1940046   1         4.0        9.0  000-1.8      38.0    NaN
# 2        V02Q1940044   1         5.0        7.0  000-1.5      33.0    NaN
# 3        V02Q1940049   1         8.0       15.0  000-1.7      33.0    NaN
# 4        V02Q1940050   1         8.0       13.0  000-2.6      36.0    NaN
# ...              ...  ..         ...        ...      ...       ...    ...
# 1855412  V02Q1940864   1         4.0        4.0     12.8      48.0    NaN
# 1855413  V02Q1940859   1         7.0        7.0     11.2      53.0    NaN
# 1855414  V02Q1940876   1         4.0        4.0     11.9      55.0    NaN
# 1855415  V02Q1940857   1         7.0        7.0      7.8      75.0    NaN
# 1855416  V02Q1940867   1         4.0        4.0     13.1      50.0    NaN
#
#          풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
S_DoT1.to_csv("S_DoT1")

# %%
S_DoT2 = pd.concat([dot_2104, dot_2105, dot_2106],ignore_index=True)
S_DoT2
# Out:
#                  시리얼 구분 초미세먼지(㎍/㎥) 미세먼지(㎍/㎥) 기온(℃) 상대습도( %)  풍향(°) 풍속(m/s)  \
# 0        OC3CL200135  1        2.0       3.0   9.9     51.0  345.0     0.7
# 1        OC3CL200147  1        3.0       6.0   9.9     54.0   43.0     0.2
# 2        OC3CL200142  1        3.0       5.0   9.5     49.0   34.0     0.7
# 3        OC3CL200132  1        2.0       4.0   5.8     81.0    NaN     NaN
# 4        OC3CL200145  1        2.0       5.0   9.5     54.0   97.0     0.3
# ...              ... ..        ...       ...   ...      ...    ...     ...
# 2281857  V02Q1940951  1          0         0  21.9     86.0    NaN     NaN
# 2281858  V02Q1940954  1          1         1  22.4     80.0    NaN     NaN
# 2281859  V02Q1941015  1          1         2  21.8     86.0    NaN     NaN
# 2281860  V02Q1941006  1          1         2  21.6     86.0    NaN     NaN
# 2281861  V02Q1941000  1          3         4  21.6     87.0    NaN     NaN
#
# ...

# %%
S_DoT2.to_csv("S_DoT2")

# %%
S_DoT3 = pd.concat([dot_2107, dot_2108, dot_2109],ignore_index=True)
S_DoT3
# Out:
#                  시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0        OC3CL200025   1         0.0        1.0   20.9     100.0    NaN
# 1        OC3CL200023   1         0.0        1.0   21.5      94.0    NaN
# 2        OC3CL200016   1         1.0        3.0   21.8      96.0    NaN
# 3        OC3CL200012   1         4.0        7.0   21.8     100.0    NaN
# 4        OC3CL200030   1         4.0        6.0   20.5     100.0    NaN
# ...              ...  ..         ...        ...    ...       ...    ...
# 2032050  V02Q1940955   1         7.0        7.0   24.2      78.0    NaN
# 2032051  V02Q1941000   1         8.0       22.0   24.0      81.0    NaN
# 2032052  V02Q1941006   1         1.0        2.0   23.3      84.0    NaN
# 2032053  V02Q1941013   1         0.0        0.0   24.4      79.0    NaN
# 2032054  V02Q1941015   1         0.0        1.0   23.1      82.0    NaN
#
#          풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
S_DoT3.to_csv("S_DoT3")

# %%
S_DoT4 = pd.concat([dot_2110, dot_2111, dot_2112],ignore_index=True)
S_DoT4
# Out:
#                  시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0        OC3CL200011   1         1.0        4.0   21.6      88.0    NaN
# 1        OC3CL200021   1         7.0       13.0   25.4      74.0    NaN
# 2        OC3CL200013   1         4.0        8.0   24.2     100.0    NaN
# 3        OC3CL200031   1         3.0        7.0   24.2     100.0    NaN
# 4        OC3CL200024   1         4.0       11.0   25.5      72.0    NaN
# ...              ...  ..         ...        ...    ...       ...    ...
# 3509201  V02Q1940955   1         6.0        6.0   -1.6      42.0    NaN
# 3509202  V02Q1941013   1         0.0        0.0   -0.3      33.0    NaN
# 3509203  V02Q1940953   1         6.0        6.0   -0.8      40.0    NaN
# 3509204  V02Q1940954   1        10.0       10.0   -0.8      40.0    NaN
# 3509205  V02Q1941000   1         1.0        2.0   -1.1      34.0    NaN
#
#          풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
S_DoT4.to_csv("S_DoT4")

# %%
S_DoT5 = pd.concat([dot_2201, dot_2202, dot_2203],ignore_index=True)
S_DoT5
# Out:
#                  시리얼  구분  초미세먼지(㎍/㎥)  미세먼지(㎍/㎥)  기온(℃)  상대습도( %)  풍향(°)  \
# 0        OC3CL200017   1         4.0        7.0   -3.0      52.0    NaN
# 1        OC3CL200014   1         7.0       11.0   -2.4      42.0    NaN
# 2        OC3CL200011   1         6.0        9.0   21.6      85.0    NaN
# 3        OC3CL200029   1        13.0       19.0   -1.2      44.0    NaN
# 4        OC3CL200027   1         7.0       11.0   -4.0      37.0    NaN
# ...              ...  ..         ...        ...    ...       ...    ...
# 1544967  V02Q1941006   1         1.0        2.0   13.1      87.0    NaN
# 1544968  V02Q1940950   1         6.0        6.0   14.0      80.0    NaN
# 1544969  V02Q1941013   1        12.0       12.0   13.9      85.0    NaN
# 1544970  V02Q1940944   1         8.0        8.0   14.0      81.0    NaN
# 1544971  V02Q1940954   1        22.0       23.0   14.7      78.0    NaN
#
#          풍속(m/s)  돌풍 풍향(°)  돌풍 풍속(m/s)  조도(lux)  자외선(UVI)  소음(dB)  진동_x(g)  \
# ...

# %%
S_DoT5.to_csv("S_DoT5")
